# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pwd
# Out:
# '/home/hza/PlasticineLab/plb/cut'

# %%
from plb.envs import make
env = make('CutRearrange-v1', nn=False)
# Out:
# [Taichi] mode=release
# [Taichi] preparing sandbox at /tmp/taichi-y_6d7vd_
# [Taichi] version 0.7.26, llvm 10.0.0, commit e37bdb5e, linux, python 3.7.11
# [I 09/28/21 17:47:06.124 2519608] [shell.py:_shell_pop_print@35] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=cuda
# [Tina] version 0.1.1
# [Tina] Taichi properties hacked
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 3
#   scale: (0.015, 0.015, 0.015)
# collision_group: [0.0, 0.0, 0.0]
# color: (0.7568, 0.6039, 0.4196)
# friction: 0.0
# h: (0.15, 0.15)
# init_pos: (0.5, 0.3, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# prot: (1.0, 0.0, 0.0, 0.58)
# shape: Knife
# size: (0.025, 0.2, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.3, 0.3, 0.3)
# friction: 0.9
# h: (0.15, 0.15)
# init_pos: (0.3, 0.3, 0.3)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# prot: (1.0, 0.0, 0.0, 0.58)
# shape:
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.3, 0.3, 0.3)
# friction: 0.9
# init_pos: (0.3, 0.3, 0.3)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape:
# size: (0.025, 0.2, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 7
#   scale: (0.015, 0.015, 0.015, 0.0, 0.0, 0.0, 0.015)
# collision_group: [0.0, 0.0, 0.0]
# color: (0.7568, 0.6039, 0.4196)
# friction: 10.0
# init_gap: 0.18
# init_pos: (0.5, 0.1, 0.5)
# init_rot: (0.707, 0.0, 0.707, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# maximal_gap: 0.2
# minimal_gap: 0.08
# round: 0
# shape: Gripper
# size: (0.015, 0.1, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.5, 0.4, 0.5)
# cam_phi: -1.0
# cam_radius: 1.0
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (512, 512)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 1024
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Tina] Hint: MMB to orbit, Shift+MMB to pan, wheel to zoom
# Env reseting to: /home/hza/PlasticineLab/plb/cut/cached_state_path/target/target_2695.npy, init v: 630, target v: 2695
# emd after reset: 0.3189752697944641
# ======================WARNING: contact loss mask not set================

# %%
import matplotlib.pyplot as plt
from imitation.env_spec import set_render_mode

set_render_mode(env, 'CutRearrange-v1')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
env.env.taichi_env.renderer.update_camera((0.52, 0.3, 0.41), 0., -1.3, 0.75)
img = env.render('rgb', img_size=512)

plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
